# %% [markdown]
# # 🇬🇭 Гана
#
# ## 🗺️ Площа
# **238,533 км²**
#
# ## 👥 Населення
# _понад 32 мільйони осіб_
#
# ## 🏛️ Державний устрій
# - Унітарна президентська республіка
# - **Президент:** Нана Акуфо-Аддо
#
# ## 👤 Відомі персоналії
# - Кофі Аннан (екс-генсек ООН)
# - Азумі Нельсон (легендарний боксер)
# - Амма Дарко (письменниця)
#
# ## 🏞️ Пам’ятки природи і культури
# - Національний парк Какум
# - Озеро Вольта
# - Форти Ельміна та Кейп-Кост (спадщина ЮНЕСКО)
#
# ---
#
# ## 🔤 Форматування тексту
# **Жирний текст**, *курсив*, `моноширинний`, ~~закреслений~~
#
# <span style="color:green">Зелений</span>, <span style="color:orange">Помаранчевий</span>, <span style="color:blue">Синій</span>
#
# ---
#
# ## 📊 Таблиця
#
# | Категорія         | Інформація          |
# |-------------------|---------------------|
# | Столиця           | Аккра               |
# | Офіційна мова     | Англійська          |
# | Валюта            | Ганський седі (GHS) |
# | Релігія           | Християнство, Іслам |
#
# ---
#
# ## 📌 Список фактів
# - Західна Африка
# - Вихід до Гвінейської затоки
# - Незалежність з 1957 року
#
# ---
#
# ## 🖼️ Зображення
#
# ![Форт Кейп-Кост](data:image/jpeg;base64,...)
#
# ---
#
# ## 🔗 Посилання
# [Стаття про Гану у Вікіпедії](https://uk.wikipedia.org/wiki/Гана)
#
# ---
#
# ## 🇬🇭 Прапор Гани (HTML SVG)
#
# ```html
# <svg width="200" height="120">
#   <rect width="200" height="40" y="0" style="fill:red"/>
#   <rect width="200" height="40" y="40" style="fill:yellow"/>
#   <rect width="200" height="40" y="80" style="fill:green"/>
#   <polygon points="100,40 108,72 80,54 120,54 92,72"
#            style="fill:black"/>
# </svg>

# %%
# 5 варіант 

def is_prime(n):
    """Перевірка, чи є число простим"""
    if n < 2:
        return False
    for i in range(2, int(n**0.5)+1):
        if n % i == 0:
            return False
    return True

def kth_prime(k):
    """Повертає k-те просте число"""
    if not isinstance(k, int) or k < 1:
        raise ValueError("k має бути цілим числом більше 0")

    count = 0
    num = 1
    while count < k:
        num += 1
        if is_prime(num):
            count += 1
    return num


try:
    k = int(input("Введіть номер простого числа (k): "))
    result = kth_prime(k)
    print(f"{k}-те просте число: {result}")
except ValueError as e:
    print("Помилка:", e)

# Тест 1
print("5-те просте число:", kth_prime(5)) 

# Тест 2
print("10-те просте число:", kth_prime(10)) 

# Тест 3
print("20-те просте число:", kth_prime(20))
# Out:
# Введіть номер простого числа (k):  15
# 15-те просте число: 47
# 5-те просте число: 11
# 10-те просте число: 29
# 20-те просте число: 71
